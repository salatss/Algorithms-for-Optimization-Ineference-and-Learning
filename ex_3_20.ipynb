# %%
include( "subset.jl")
# Out:
# sum! (generic function with 2 methods)

# %%
#es 3
using Plots
start_x=[1,2,1,NaN]
start_y=[1,1,2,NaN]
tri=serpinzky(start_x,start_y)

gr()
plot(Shape(tri[1],tri[2]))

# %%
#es 11
z=comboss(3,2)
# Out:
# 3-element Array{Any,1}:
#  Any[1, 2]
#  Any[1, 3]
#  Any[2, 3]

# %%
#es 15
z=power_efficiency(3)
# Out:
# Dict{Any,Any} with 3 entries:
#   "2"      => true
#   "square" => 1
#   "molt"   => 1

# %%
#es 16
include( "subset.jl")
z=collect(1:5)
knapsack(z)
# Out:
# knaps(Float16(1.0), [3, 5], Any[1, 2, 4])

# %%
struct knaps
    diff::Int                    
    v::Vector{Int}    
    w::Vector{Int}
end
a=[]
z=knaps(1,[1,2,3],[7,9,8,1])
push!(a,z)
push!(a,knaps(3,[1,2,3],[7,9,8,1]))
push!(a,knaps(0,[1,2,3],[7,9,8,1]))


argmin( [a[i].diff for i in 1:length(a)] )
# Out:
# invalid redefinition of constant knaps
#
# Stacktrace:
#  [1] top-level scope at /home/salats/.julia/packages/IJulia/nglnM/src/kernel.jl:52

# %%
collect(1:15)
z=rand(collect(1:10))
# Out:
# 9
